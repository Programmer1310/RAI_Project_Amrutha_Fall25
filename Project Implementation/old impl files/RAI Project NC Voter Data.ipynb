# %%
# !pip install pyethnicity
# Out:
# Collecting pyethnicity
#   Downloading pyethnicity-0.0.27-py3-none-any.whl.metadata (4.0 kB)
# Collecting onnxruntime-gpu (from pyethnicity)
#   Downloading onnxruntime_gpu-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: polars>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyethnicity) (1.31.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from pyethnicity) (18.1.0)
# Collecting pycutils (from pyethnicity)
#   Downloading pycutils-0.1.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pyethnicity) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pyethnicity) (4.67.1)
# Collecting coloredlogs (from onnxruntime-gpu->pyethnicity)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->pyethnicity) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->pyethnicity) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->pyethnicity) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->pyethnicity) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->pyethnicity) (1.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pyethnicity) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pyethnicity) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pyethnicity) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pyethnicity) (2025.11.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu->pyethnicity)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu->pyethnicity) (1.3.0)
# Downloading pyethnicity-0.0.27-py3-none-any.whl (38.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.8/38.8 MB 27.2 MB/s eta 0:00:00
# Downloading onnxruntime_gpu-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (300.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.5/300.5 MB 4.3 MB/s eta 0:00:00
# Downloading pycutils-0.1.1-py3-none-any.whl (6.1 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.1 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: pycutils, humanfriendly, coloredlogs, onnxruntime-gpu, pyethnicity
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-gpu-1.23.2 pycutils-0.1.1 pyethnicity-0.0.27

# %%
import pandas as pd
import os
from multiprocessing import Pool, cpu_count
import numpy as np

# %%
base_path = "/content/drive/MyDrive/RAI Project/Project Implementation"
folder_path = base_path + "/ncvotersheets"
if not os.path.exists(folder_path):
    print(f"Error: The folder '{folder_path}' does not exist. Please ensure it's created and accessible.")
else:
    all_files_and_dirs = os.listdir(folder_path)

    excel_files = [f for f in all_files_and_dirs if f.startswith('ncvoter') and f.endswith('.xlsx')]

    print(f"Found {len(excel_files)} Excel files matching 'ncvoter*.xlsx' in '{folder_path}':")
    # for file_name in excel_files:
    #     print(file_name)
    excel_files_top10 = excel_files[:10]
    print(excel_files_top10)
# Out:
# Found 99 Excel files matching 'ncvoter*.xlsx' in '/content/drive/MyDrive/RAI Project/Project Implementation/ncvotersheets':
# ['ncvoter28.xlsx', 'ncvoter1.xlsx', 'ncvoter2.xlsx', 'ncvoter10.xlsx', 'ncvoter3.xlsx', 'ncvoter29.xlsx', 'ncvoter4.xlsx', 'ncvoter30.xlsx', 'ncvoter6.xlsx', 'ncvoter31.xlsx']

# %%
# list of columns to keep
columns_to_keep = [
    'first_name',
    'last_name',
    'middle_name',
    'county_id',
    'county_desc',
    'race_code',
    'ethnic_code',
    'zip_code',
    'reason_cd',
    'party_cd',
    'gender_code',
    'age_at_year_end',
    'drivers_lic',
    'birth_state',
    'registr_dt'
]

print("Columns to keep defined:", columns_to_keep)
# Out:
# Columns to keep defined: ['first_name', 'last_name', 'middle_name', 'county_id', 'county_desc', 'race_code', 'ethnic_code', 'zip_code']

# %%
# List to store processed DataFrames
processed_dataframes = []

# Create a folder to save processed files (if needed, or for combined output)
output_folder = os.path.join(folder_path, 'processed_ncvoter_sheets')
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Created output folder: {output_folder}")

print("Starting to process Excel files...")
total = 99
count = 0
# for file_name in excel_files_top10:
for file_name in excel_files:
    file_path = os.path.join(folder_path, file_name)
    try:
        # Read the Excel file into a pandas DataFrame
        df = pd.read_excel(file_path)
        count += 1

        # # Select only the desired columns
        # # Handle cases where some columns might be missing in a specific file
        existing_columns = [col for col in columns_to_keep if col in df.columns]
        processed_df = df[existing_columns]

        if 'reason_cd' in processed_df.columns:
            initial_rows_before_filter = len(processed_df)
            processed_df = processed_df[processed_df['reason_cd'] != 'RM']
            removed_rows_count = initial_rows_before_filter - len(processed_df)
            if removed_rows_count > 0:
                print(f"Removed {removed_rows_count} rows with 'RM' in 'reason_cd' from '{file_name}'")

        processed_dataframes.append(processed_df)

        print(f"Successfully processed '{file_name}'). Remaining: {total - count}")

    except FileNotFoundError:
        print(f"Error: File not found at '{file_path}'. Skipping this file.")
    except KeyError as e:
        print(f"Error processing '{file_name}': Missing expected column(s). {e}")
    except Exception as e:
        print(f"An unexpected error occurred while processing '{file_name}': {e}")

print(f"Finished processing {len(excel_files)} files. {len(processed_dataframes)} DataFrames were successfully processed.")
# Out:
# Starting to process Excel files...
# Successfully processed 'ncvoter28.xlsx'). Remaining: 98
# Successfully processed 'ncvoter1.xlsx'). Remaining: 97
# Successfully processed 'ncvoter2.xlsx'). Remaining: 96
# Successfully processed 'ncvoter10.xlsx'). Remaining: 95
# Successfully processed 'ncvoter3.xlsx'). Remaining: 94
# Successfully processed 'ncvoter29.xlsx'). Remaining: 93
# Successfully processed 'ncvoter4.xlsx'). Remaining: 92
# Successfully processed 'ncvoter30.xlsx'). Remaining: 91
# Successfully processed 'ncvoter6.xlsx'). Remaining: 90
# Successfully processed 'ncvoter31.xlsx'). Remaining: 89
# Successfully processed 'ncvoter7.xlsx'). Remaining: 88
# Successfully processed 'ncvoter8.xlsx'). Remaining: 87
# Successfully processed 'ncvoter9.xlsx'). Remaining: 86
# Successfully processed 'ncvoter37.xlsx'). Remaining: 85
# Successfully processed 'ncvoter38.xlsx'). Remaining: 84
# Successfully processed 'ncvoter39.xlsx'). Remaining: 83
# Successfully processed 'ncvoter40.xlsx'). Remaining: 82
# Successfully processed 'ncvoter11.xlsx'). Remaining: 81
# Successfully processed 'ncvoter32.xlsx'). Remaining: 80
# Successfully processed 'ncvoter33.xlsx'). Remaining: 79
# Successfully processed 'ncvoter12.xlsx'). Remaining: 78
# Successfully processed 'ncvoter13.xlsx'). Remaining: 77
# Successfully processed 'ncvoter14.xlsx'). Remaining: 76
# Successfully processed 'ncvoter15.xlsx'). Remaining: 75
# Successfully processed 'ncvoter16.xlsx'). Remaining: 74
# Successfully processed 'ncvoter17.xlsx'). Remaining: 73
# Successfully processed 'ncvoter18.xlsx'). Remaining: 72
# Successfully processed 'ncvoter46.xlsx'). Remaining: 71
# Successfully processed 'ncvoter47.xlsx'). Remaining: 70
# Successfully processed 'ncvoter48.xlsx'). Remaining: 69
# Successfully processed 'ncvoter49.xlsx'). Remaining: 68
# Successfully processed 'ncvoter50.xlsx'). Remaining: 67
# Successfully processed 'ncvoter51.xlsx'). Remaining: 66
# Successfully processed 'ncvoter52.xlsx'). Remaining: 65
# Successfully processed 'ncvoter53.xlsx'). Remaining: 64
# Successfully processed 'ncvoter41.xlsx'). Remaining: 63
# Successfully processed 'ncvoter54.xlsx'). Remaining: 62
# Successfully processed 'ncvoter34.xlsx'). Remaining: 61
# Successfully processed 'ncvoter55.xlsx'). Remaining: 60
# Successfully processed 'ncvoter56.xlsx'). Remaining: 59
# Successfully processed 'ncvoter57.xlsx'). Remaining: 58
# Successfully processed 'ncvoter35.xlsx'). Remaining: 57
# Successfully processed 'ncvoter64.xlsx'). Remaining: 56
# Successfully processed 'ncvoter42.xlsx'). Remaining: 55
# Successfully processed 'ncvoter43.xlsx'). Remaining: 54
# Successfully processed 'ncvoter44.xlsx'). Remaining: 53
# Successfully processed 'ncvoter36.xlsx'). Remaining: 52
# Successfully processed 'ncvoter73.xlsx'). Remaining: 51
# Successfully processed 'ncvoter65.xlsx'). Remaining: 50
# Successfully processed 'ncvoter66.xlsx'). Remaining: 49
# Successfully processed 'ncvoter45.xlsx'). Remaining: 48
# Successfully processed 'ncvoter82.xlsx'). Remaining: 47
# Successfully processed 'ncvoter91.xlsx'). Remaining: 46
# Successfully processed 'ncvoter74.xlsx'). Remaining: 45
# Successfully processed 'ncvoter75.xlsx'). Remaining: 44
# Successfully processed 'ncvoter67.xlsx'). Remaining: 43
# Successfully processed 'ncvoter76.xlsx'). Remaining: 42
# Successfully processed 'ncvoter68.xlsx'). Remaining: 41
# Successfully processed 'ncvoter77.xlsx'). Remaining: 40
# Successfully processed 'ncvoter69.xlsx'). Remaining: 39
# Successfully processed 'ncvoter78.xlsx'). Remaining: 38
# Successfully processed 'ncvoter100.xlsx'). Remaining: 37
# Successfully processed 'ncvoter70.xlsx'). Remaining: 36
# Successfully processed 'ncvoter71.xlsx'). Remaining: 35
# Successfully processed 'ncvoter92.xlsx'). Remaining: 34
# Successfully processed 'ncvoter93.xlsx'). Remaining: 33
# Successfully processed 'ncvoter94.xlsx'). Remaining: 32
# Successfully processed 'ncvoter95.xlsx'). Remaining: 31
# Successfully processed 'ncvoter58.xlsx'). Remaining: 30
# Successfully processed 'ncvoter62.xlsx'). Remaining: 29
# Successfully processed 'ncvoter59.xlsx'). Remaining: 28
# Successfully processed 'ncvoter72.xlsx'). Remaining: 27
# Successfully processed 'ncvoter63.xlsx'). Remaining: 26
# Successfully processed 'ncvoter79.xlsx'). Remaining: 25
# Successfully processed 'ncvoter83.xlsx'). Remaining: 24
# Successfully processed 'ncvoter84.xlsx'). Remaining: 23
# Successfully processed 'ncvoter80.xlsx'). Remaining: 22
# Successfully processed 'ncvoter85.xlsx'). Remaining: 21
# Successfully processed 'ncvoter81.xlsx'). Remaining: 20
# Successfully processed 'ncvoter86.xlsx'). Remaining: 19
# Successfully processed 'ncvoter89.xlsx'). Remaining: 18
# Successfully processed 'ncvoter87.xlsx'). Remaining: 17
# Successfully processed 'ncvoter88.xlsx'). Remaining: 16
# Successfully processed 'ncvoter96.xlsx'). Remaining: 15
# Successfully processed 'ncvoter97.xlsx'). Remaining: 14
# Successfully processed 'ncvoter98.xlsx'). Remaining: 13
# Successfully processed 'ncvoter90.xlsx'). Remaining: 12
# Successfully processed 'ncvoter99.xlsx'). Remaining: 11
# Successfully processed 'ncvoter60.xlsx'). Remaining: 10
# Successfully processed 'ncvoter61.xlsx'). Remaining: 9
# Successfully processed 'ncvoter21.xlsx'). Remaining: 8
# Successfully processed 'ncvoter22.xlsx'). Remaining: 7
# Successfully processed 'ncvoter20.xlsx'). Remaining: 6
# Successfully processed 'ncvoter24.xlsx'). Remaining: 5
# Successfully processed 'ncvoter23.xlsx'). Remaining: 4
# Successfully processed 'ncvoter25.xlsx'). Remaining: 3
# Successfully processed 'ncvoter27.xlsx'). Remaining: 2
# Successfully processed 'ncvoter26.xlsx'). Remaining: 1
# Successfully processed 'ncvoter5.xlsx'). Remaining: 0
# Finished processing 99 files. 99 DataFrames were successfully processed.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Combine all processed DataFrames into a single DataFrame
if processed_dataframes:
    combined_df = pd.concat(processed_dataframes, ignore_index=True)
    print(f"Combined all processed data into a single DataFrame with {len(combined_df)} rows.")
    print(combined_df.head())
    # Save the combined DataFrame to a new Excel file
#     output_file_path = os.path.join(output_folder, 'combined_ncvoter_data.xlsx')
#     combined_df.to_excel(output_file_path, index=False)
#     print(f"Combined data saved to: '{output_file_path}'")
#     display(combined_df.head())
# else:
#     print("No dataframes were successfully processed to combine.")
# Out:
# Combined all processed data into a single DataFrame with 8892736 rows.
#   first_name last_name middle_name  county_id county_desc race_code  \
# 0      AARON     AARON       JAMES         28        DARE         W
# 1    MATTHEW     AARON      JORDAN         28        DARE         W
# 2      SHANE     AARON      LANDON         28        DARE         W
# 3       TARA     AARON     STAPLES         28        DARE         W
# 4    ANTHONY     ABATE      JOSEPH         28        DARE         W
#
#   ethnic_code  zip_code
# 0          UN   27943.0
# 1          UN       NaN
# 2          NL   27943.0
# 3          UN   27943.0
# 4          UN   27959.0

# %%
#Removing an zipcodes which are NaN
initial_rows = len(combined_df)
combined_df = combined_df.dropna(subset=['zip_code'])
final_rows = len(combined_df)

print(f"Removed {initial_rows - final_rows} rows with empty or NaN zip codes.")
print(f"Combined DataFrame now has {final_rows} rows.")
print(combined_df.head())
# Out:
# Removed 1290766 rows with empty or NaN zip codes.
# Combined DataFrame now has 7601970 rows.
#   first_name last_name middle_name  county_id county_desc race_code  \
# 0      AARON     AARON       JAMES         28        DARE         W
# 2      SHANE     AARON      LANDON         28        DARE         W
# 3       TARA     AARON     STAPLES         28        DARE         W
# 4    ANTHONY     ABATE      JOSEPH         28        DARE         W
# 5   LORRAINE     ABATE       MARIE         28        DARE         W
#
#   ethnic_code  zip_code
# 0          UN   27943.0
# 2          NL   27943.0
# 3          UN   27943.0
# 4          UN   27959.0
# 5          UN   27959.0

# %%
#If the ethnic_code column contains HL and the race_code column contains U(undesignated) then we will set
#the value of race_code column as HL

initial_u_hl_count = len(combined_df[(combined_df['ethnic_code'] == 'HL') & (combined_df['race_code'] == 'U')])

combined_df.loc[
    (combined_df['ethnic_code'] == 'HL') & (combined_df['race_code'] == 'U'),
    'race_code'
] = 'HL'

final_u_hl_count = len(combined_df[(combined_df['ethnic_code'] == 'HL') & (combined_df['race_code'] == 'U')])

print(f"Number of rows where ethnic_code was 'HL' and race_code was 'U' before update: {initial_u_hl_count}")
print(f"Number of rows updated: {initial_u_hl_count - final_u_hl_count}")
print(f"Number of rows where ethnic_code is 'HL' and race_code is still 'U' after update: {final_u_hl_count}")

# Display the first few rows to show the change
print("\nDataFrame head after update (showing relevant columns):")
print(combined_df[combined_df['ethnic_code'] == 'HL'][['ethnic_code', 'race_code']].head())
# Out:
# Number of rows where ethnic_code was 'HL' and race_code was 'U' before update: 58552
# Number of rows updated: 58552
# Number of rows where ethnic_code is 'HL' and race_code is still 'U' after update: 0
#
# DataFrame head after update (showing relevant columns):
#     ethnic_code race_code
# 34           HL        HL
# 41           HL         O
# 56           HL         W
# 67           HL         W
# 175          HL         W

# %%
# --- Parameters ---
TARGET_SAMPLE_SIZE = 200000
STRATIFICATION_COLUMN = 'race_code'
# ------------------


race_proportions = combined_df[STRATIFICATION_COLUMN].value_counts(normalize=True)

sample_counts = (race_proportions * TARGET_SAMPLE_SIZE).round().astype(int)

stratified_samples = []

print("Sampling distribution:")
print(sample_counts)

for race_code, count in sample_counts.items():

    subset = combined_df[combined_df[STRATIFICATION_COLUMN] == race_code]

    sample = subset.sample(n=count, replace=False, random_state=42)

    stratified_samples.append(sample)

df_sampled = pd.concat(stratified_samples).reset_index(drop=True)

df_sampled = df_sampled.sample(frac=1, random_state=42).reset_index(drop=True)

print(f"\nOriginal size: {len(combined_df)}")
print(f"Sampled size: {len(df_sampled)}")

original_dist = combined_df[STRATIFICATION_COLUMN].value_counts(normalize=True).sort_index()
sampled_dist = df_sampled[STRATIFICATION_COLUMN].value_counts(normalize=True).sort_index()


comparison_table = pd.DataFrame({
    'Original Proportion': original_dist,
    'Sampled Proportion': sampled_dist
})
print("\nDistribution Comparison:")
print(comparison_table.mul(100).round(2).astype(str) + '%')


sample_file_name = 'stratified_sample_' + str(TARGET_SAMPLE_SIZE) + '.csv'

df_sampled.to_csv(sample_file_name, index=False)

print(f"Successfully saved the new dataset to {sample_file_name}")
# Out:
# Sampling distribution:
# race_code
# W     63154
# B     20071
# U      8945
# O      4311
# A      1825
# HL      795
# M       488
# I       398
# P        14
#           0
# Name: proportion, dtype: int64
#
# Original size: 7601970
# Sampled size: 100001
#
# Distribution Comparison:
#           Original Proportion Sampled Proportion
# race_code
#                          0.0%               nan%
# A                       1.82%              1.82%
# B                      20.07%             20.07%
# HL                      0.79%              0.79%
# I                        0.4%               0.4%
# M                       0.49%              0.49%
# O                       4.31%              4.31%
# P                       0.01%              0.01%
# U                       8.94%              8.94%
# W                      63.15%             63.15%
# Successfully saved the new dataset to 'stratified_sample_100k.csv'

# %%
count_a = 0
count_b = 0
count_i = 0
count_m = 0
count_o = 0
count_p = 0
count_w = 0
count_u = 0
count_h = 0
count_n = 0
m_set = ""
#iterate over each value in the column race_code
for value in combined_df['race_code']:
    if value == 'A':
        count_a += 1
    elif value == 'B':
        count_b += 1
    elif value == 'I':
        count_i += 1
    elif value == 'M':
        count_m +=1
    elif value == 'O':
        count_o +=1
    elif value == 'P':
        count_p +=1
    elif value == 'W':
        count_w +=1
    elif value == 'U':
        count_u +=1
    elif value == 'HL':
        count_h +=1
    else:
      m_set = value
      count_n += 1
print("count_a = " + str(count_a))
print("count_b = " + str(count_b))
print("count_i = " + str(count_i))
print("count_m = " + str(count_m))
print("count_o = " + str(count_o))
print("count_p = " + str(count_p))
print("count_w = " + str(count_w))
print("count_u = " + str(count_u))
print("count_h = " + str(count_h))
print("total = " + str(count_a + count_b + count_i + count_m + count_o + count_p + count_w + count_u + count_h))
print("count_n = " + str(count_n) + " set: " + m_set)
# Out:
# count_a = 134421
# count_b = 1478641
# count_i = 29351
# count_m = 35979
# count_o = 317584
# count_p = 1031
# count_w = 4652691
# count_u = 658978
# count_h = 58552
# total = 7367228
# count_n = 234742 set:

# %%
# Crosswalk file showing the mapping between ZIP code and ZCTA
crosswalk_file_path = os.path.join(base_path, 'ZIP Code to ZCTA Crosswalk.xlsx')
print(crosswalk_file_path)
# Out:
# /content/drive/MyDrive/RAI Project/Project Implementation/ZIP Code to ZCTA Crosswalk.xlsx

# %%
try:
  crosswalk_df = pd.read_excel(crosswalk_file_path)
  print(f"Successfully loaded '{crosswalk_file_path}'.")
  print("Crosswalk DataFrame head:")
  print(crosswalk_df.head())

  # Convert zip_code in df_sampled to numeric for merging if it's not already
  df_sampled['zip_code'] = pd.to_numeric(df_sampled['zip_code'], errors='coerce')
  # # Ensure ZIP_CODE in crosswalk_df is numeric
  crosswalk_df['ZIP_CODE'] = pd.to_numeric(crosswalk_df['ZIP_CODE'], errors='coerce')

  # Merge df_sampled with crosswalk_df to get the 'zcta' column
  # We'll use a left merge to keep all rows from df_sampled
  df_with_zcta = pd.merge(
      df_sampled,
      crosswalk_df[['ZIP_CODE', 'zcta']],
      left_on='zip_code',
      right_on='ZIP_CODE',
      how='left'
  )

  df_with_zcta = df_with_zcta.drop(columns=['ZIP_CODE'], errors='ignore') # errors='ignore' if ZIP_CODE column wasn't merged

  df_with_zcta['zcta'] = df_with_zcta['zcta'].astype('Int64')
  df_with_zcta['zip_code'] = df_with_zcta['zip_code'].astype('Int64')

  print("\n'zcta' column added to df_with_zcta.")
  print(df_with_zcta.head())

except FileNotFoundError:
    print(f"Error: Crosswalk file not found at '{crosswalk_file_path}'. Please ensure the file exists.")
except Exception as e:
    print(f"An error occurred while processing the crosswalk file or merging: {e}")
# Out:
# Successfully loaded '/content/drive/MyDrive/RAI Project/Project Implementation/ZIP Code to ZCTA Crosswalk.xlsx'.
# Crosswalk DataFrame head:
#    ZIP_CODE        PO_NAME STATE       ZIP_TYPE     zcta     zip_join_type
# 0     77982  Port O Connor    TX  Zip Code Area  77982.0  Zip matches ZCTA
# 1     77983       Seadrift    TX  Zip Code Area  77983.0  Zip matches ZCTA
# 2     78860       El Indio    TX  Zip Code Area  78860.0  Zip matches ZCTA
# 3     77950       Austwell    TX  Zip Code Area  77950.0  Zip matches ZCTA
# 4     77990         Tivoli    TX  Zip Code Area  77990.0  Zip matches ZCTA
#
# 'zcta' column added to df_with_zcta.
#   first_name last_name middle_name  county_id  county_desc race_code  \
# 0     GERALD    MADDOX         NaN         94   WASHINGTON         W
# 1    MADELYN    BADGER       LAURA         34      FORSYTH         W
# 2      KACIE    WATSON    MICHELLE         60  MECKLENBURG         W
# 3    MICHAEL    MELTON      BAILEY         23    CLEVELAND         W
# 4    EARLENE   WHITLOW         KAY         36       GASTON         W
#
#   ethnic_code  zip_code   zcta
# 0          NL     27970  27970
# 1          NL     27104  27104
# 2          NL     28269  28269
# 3          NL     28150  28150
# 4          NL     28034  28034

# %%
df_with_zcta.to_csv('df_with_zcta.csv', index=False)
print("DataFrame 'df_with_zcta' saved to 'df_with_zcta.csv'")
# Out:
# DataFrame 'df_with_zcta' saved to 'df_with_zcta.csv'

# %%
loaded_df_with_zcta = pd.read_csv('df_with_zcta.csv')
print("DataFrame 'df_with_zcta.csv' loaded successfully.")
print(loaded_df_with_zcta.head())
# Out:
# DataFrame 'df_with_zcta.csv' loaded successfully.
#   first_name last_name middle_name  county_id  county_desc race_code  \
# 0     GERALD    MADDOX         NaN         94   WASHINGTON         W
# 1    MADELYN    BADGER       LAURA         34      FORSYTH         W
# 2      KACIE    WATSON    MICHELLE         60  MECKLENBURG         W
# 3    MICHAEL    MELTON      BAILEY         23    CLEVELAND         W
# 4    EARLENE   WHITLOW         KAY         36       GASTON         W
#
#   ethnic_code  zip_code   zcta
# 0          NL     27970  27970
# 1          NL     27104  27104
# 2          NL     28269  28269
# 3          NL     28150  28150
# 4          NL     28034  28034

# %%
df_shuffled_reset_index = loaded_df_with_zcta.sample(frac=1, random_state=42).reset_index(drop=True)
print("DataFrame shuffled and index reset:")
print(df_shuffled_reset_index.head())
# Out:
# DataFrame shuffled and index reset:
#   first_name last_name middle_name  county_id  county_desc race_code  \
# 0     ROBERT   PURCELL           L         92         WAKE         W
# 1     TRAVIS    THOMAS     MICHAEL         43      HARNETT         W
# 2      GLENN     EVANS         NaN         60  MECKLENBURG         W
# 3       SETH     BERRY       JACOB         98       WILSON         W
# 4    MICHAEL  CRAWFORD      EUGENE         49      IREDELL         W
#
#   ethnic_code  zip_code   zcta
# 0          NL     27511  27511
# 1          UN     27546  27546
# 2          NL     28262  28262
# 3          UN     27893  27893
# 4          NL     28166  28166

# %%
'''df_shuffled_reset_index = df_with_zcta.sample(frac=1).reset_index(drop=True)
print("\nShuffled DataFrame (with reset index):")
print(df_shuffled_reset_index)'''
# Out:
# Shuffled DataFrame (with reset index):
#        first_name last_name middle_name  county_id  county_desc race_code  \
# 0         PATRICK    LOHMAN        NEAL         92         WAKE         W
# 1         SHIRLEY  GILLYARD       JONES         25       CRAVEN         B
# 2           LARRY    GRAHAM     DONNELL         43      HARNETT         B
# 3           ELLEN  CUSTALOW      TYRONE         42      HALIFAX         B
# 4          BEENTA     PATEL      HARDIK         41     GUILFORD         A
# ...           ...       ...         ...        ...          ...       ...
# 99996       SANDY    ROGERS         NaN         34      FORSYTH         W
# 99997     CHARLES   SUNDEEN      AUSTIN         58       MARTIN         W
# 99998   CONSTANCE    DUNCAN     ERICSON         60  MECKLENBURG         W
# 99999      SAMUEL      WEBB     OTISLEE         11     BUNCOMBE         W
# 100000      SUSAN  SCHAFFER        HILL         10    BRUNSWICK         W
#
#        ethnic_code  zip_code   zcta  prob_white  prob_black  prob_hisp  \
# 0               NL     27526  27526    0.992334    0.004552   0.002328
# 1               NL     28560  28560    0.049016    0.950206   0.000713
# 2               UN     27501  27501    0.702494    0.293812   0.003601
# 3               HL     27870  27870    0.694812    0.302657   0.000464
# 4               NL     27310  27310         NaN         NaN        NaN
# ...            ...       ...    ...         ...         ...        ...
# 99996           NL     27127  27127    0.504033    0.452086   0.037133
# 99997           UN     27846  27846    0.995736    0.003538   0.000675
# 99998           NL     28277  28277    0.831845    0.162433   0.001853
# 99999           NL     28701  28701    0.980937    0.014531   0.004261
# 100000          UN     28465  28465    0.999510    0.000119   0.000252
#
#         prob_asian
# 0         0.000786
# 1         0.000065
# 2         0.000093
# 3         0.002066
# 4              NaN
# ...            ...
# 99996     0.006749
# 99997     0.000050
# 99998     0.003869
# 99999     0.000271
# 100000    0.000119
#
# [100001 rows x 13 columns]

# %%
import pyethnicity
count = 0;
print("Conducting bifsg for the first five records of df_with_zcta:")
for index, row in df_shuffled_reset_index.iterrows():
    first_name = row['first_name']
    last_name = row['last_name']
    zcta_value = row['zcta']

    count +=1

    if count % 1000 == 0:
      print(f"\nProcessing record {index+1}") #: First Name='{first_name}', Last Name='{last_name}', ZCTA='{zcta_value}'")
    try:
        result = pyethnicity.bifsg(
            first_name,
            last_name,
            zcta_value,
            "zcta"
        )

        # print(result)
        df_shuffled_reset_index.loc[row.name, 'prob_white'] = result['white'].item()
        df_shuffled_reset_index.loc[row.name, 'prob_black'] = result['black'].item()
        df_shuffled_reset_index.loc[row.name, 'prob_hisp'] = result['hispanic'].item()
        df_shuffled_reset_index.loc[row.name, 'prob_asian'] = result['asian'].item()

        # print(row['race_code'])
    except Exception as e:
        print(f"Error conducting bifsg for this record: {e}")
print(df_with_zcta.head() )
df_shuffled_reset_index.to_csv('bisg_done_sample.csv', index=False)
# Out:
# Conducting bifsg for the first five records of df_with_zcta:
#
# Processing record 1000
#
# Processing record 2000
#
# Processing record 3000
#
# Processing record 4000
#
# Processing record 5000
#
# Processing record 6000
#
# Processing record 7000
#
# Processing record 8000
#
# Processing record 9000
# Error conducting bifsg for this record: expected String type, got: f64
#
# Resolved plan until failure:
#
# 	---> FAILED HERE RESOLVING 'sink' <---
#  WITH_COLUMNS:
#  [col("last_name_raw").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (dyn int: 1)])).list.join([" "]).alias("last_name_clean"), col("last_name_raw_1").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (dyn int: 1)])).list.join([" "]).alias("last_name_clean_1"), col("last_name_raw_2").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (dyn int: 1)])).list.join([" "]).alias("last_name_clean_2"), col("first_name_raw").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (dyn int: 1)])).list.join([" "]).alias("first_name_clean")]
#   UNNEST by:[fields]
#      WITH_COLUMNS:
#      [col("last_name_raw").str.split_exact(["-"]).struct.rename_fields(["last_name_raw_1", "last_name_raw_2"])().alias("fields")]
#       ROW_INDEX
#         UNIQUE[maintain_order: false, keep_strategy: Any] BY None
#           FILTER [(col("zcta").is_not_null()) | (col("tract").is_not_null())]
#           FROM
#             FILTER col("last_name_raw").is_not_null().cast(Boolean)
#             FROM
#               DF ["zcta", "tract", "first_name_raw", "last_name_raw"]; PROJECT */4 COLUMNS
#
# Processing record 10000
#
# Processing record 11000
#
# Processing record 12000
#
# Processing record 13000
#
# Processing record 14000
#
# Processing record 15000
#
# Processing record 16000
#
# Processing record 17000
#
# Processing record 18000
#
# Processing record 19000
#
# Processing record 20000
#
# Processing record 21000
#
# Processing record 22000
#
# Processing record 23000
#
# Processing record 24000
#
# Processing record 25000
#
# Processing record 26000
#
# Processing record 27000
#
# Processing record 28000
# Error conducting bifsg for this record: expected String type, got: f64
#
# Resolved plan until failure:
#
# 	---> FAILED HERE RESOLVING 'sink' <---
#  WITH_COLUMNS:
#  [col("last_name_raw").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (dyn int: 1)])).list.join([" "]).alias("last_name_clean"), col("last_name_raw_1").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (1)])).list.join([" "]).alias("last_name_clean_1"), col("last_name_raw_2").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (1)])).list.join([" "]).alias("last_name_clean_2"), col("first_name_raw").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (1)])).list.join([" "]).alias("first_name_clean")]
#   UNNEST by:[fields]
#      WITH_COLUMNS:
#      [col("last_name_raw").str.split_exact(["-"]).struct.rename_fields(["last_name_raw_1", "last_name_raw_2"])().alias("fields")]
#       ROW_INDEX
#         UNIQUE[maintain_order: false, keep_strategy: Any] BY None
#           FILTER [(col("zcta").is_not_null()) | (col("tract").is_not_null())]
#           FROM
#             FILTER col("last_name_raw").is_not_null().cast(Boolean)
#             FROM
#               DF ["zcta", "tract", "first_name_raw", "last_name_raw"]; PROJECT */4 COLUMNS
#
# Processing record 29000
#
# Processing record 30000
#
# Processing record 31000
#
# Processing record 32000
#
# Processing record 33000
#
# Processing record 34000
#
# Processing record 35000
#
# Processing record 36000
#
# Processing record 37000
#
# Processing record 38000
#
# Processing record 39000
#
# Processing record 40000
#
# Processing record 41000
#
# Processing record 42000
#
# Processing record 43000
#
# Processing record 44000
#
# Processing record 45000
#
# Processing record 46000
# Error conducting bifsg for this record: expected String type, got: f64
#
# Resolved plan until failure:
#
# 	---> FAILED HERE RESOLVING 'sink' <---
#  WITH_COLUMNS:
#  [col("last_name_raw").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (dyn int: 1)])).list.join([" "]).alias("last_name_clean"), col("last_name_raw_1").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (1)])).list.join([" "]).alias("last_name_clean_1"), col("last_name_raw_2").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (1)])).list.join([" "]).alias("last_name_clean_2"), col("first_name_raw").str.uppercase().str.replace(["\s?J\.*?R\.*\s*?$", ""]).str.replace(["\s?S\.*?R\.*\s*?$", ""]).str.replace(["\s?III\s*?$", ""]).str.replace(["\s?IV\s*?$", ""]).str.replace(["0", ""]).str.replace(["1", ""]).str.replace(["2", ""]).str.replace(["3", ""]).str.replace(["4", ""]).str.replace(["5", ""]).str.replace(["6", ""]).str.replace(["7", ""]).str.replace(["8", ""]).str.replace(["9", ""]).str.replace(["!", ""]).str.replace([""", ""]).str.replace(["#", ""]).str.replace(["$", ""]).str.replace(["%", ""]).str.replace(["&", ""]).str.replace(["'", ""]).str.replace(["(", ""]).str.replace([")", ""]).str.replace(["*", ""]).str.replace(["+", ""]).str.replace([",", ""]).str.replace(["-", ""]).str.replace([".", ""]).str.replace(["/", ""]).str.replace([":", ""]).str.replace([";", ""]).str.replace(["<", ""]).str.replace(["=", ""]).str.replace([">", ""]).str.replace(["?", ""]).str.replace(["@", ""]).str.replace(["[", ""]).str.replace(["\", ""]).str.replace(["]", ""]).str.replace(["^", ""]).str.replace(["_", ""]).str.replace(["`", ""]).str.replace(["{", ""]).str.replace(["|", ""]).str.replace(["}", ""]).str.replace(["~", ""]).str.replace([" ", ""]).str.replace(["	", ""]).str.replace(["
# ", ""]).str.replace(["", ""]).str.replace(["", ""]).str.split([" "]).list.eval(col("").filter([(col("").str.len_bytes()) > (1)])).list.join([" "]).alias("first_name_clean")]
#   UNNEST by:[fields]
#      WITH_COLUMNS:
#      [col("last_name_raw").str.split_exact(["-"]).struct.rename_fields(["last_name_raw_1", "last_name_raw_2"])().alias("fields")]
#       ROW_INDEX
#         UNIQUE[maintain_order: false, keep_strategy: Any] BY None
#           FILTER [(col("zcta").is_not_null()) | (col("tract").is_not_null())]
#           FROM
#             FILTER col("last_name_raw").is_not_null().cast(Boolean)
#             FROM
#               DF ["zcta", "tract", "first_name_raw", "last_name_raw"]; PROJECT */4 COLUMNS
#
# Processing record 47000
#
# Processing record 48000
#
# Processing record 49000
#
# Processing record 50000

# %%
df_with_zcta.to_csv('bisg_done_sample12.csv', index=False)

# %%
def evaluate_cutoff(df, race_col, true_col, cutoff):
    """
    Compute sensitivity and specificity for a given race and cutoff.

    race_col = column with predicted probability for the race (e.g. "prob_black")
    true_col = column with the true race label (e.g. "race_code")
    cutoff   = threshold to test (0.50 ... 1.00)
    """

    # predicted positives (assigned to the race)
    pred_positive = df[race_col] > cutoff

    # true positives (actual race members)
    true_positive = df[true_col] == race_col.replace("prob_", "")

    # sensitivity = TP / actual positives
    sensitivity = (pred_positive & true_positive).sum() / true_positive.sum()

    # specificity = TN / actual negatives
    specificity = ((~pred_positive) & (~true_positive)).sum() / (~true_positive).sum()

    return sensitivity, specificity

# %%
def find_optimal_cutoff(df, race_col, true_col):
    cutoffs = np.arange(0.50, 1.01, 0.01)

    results = []

    for cutoff in cutoffs:
        sens, spec = evaluate_cutoff(df, race_col, true_col, cutoff)
        distance = np.sqrt((1 - sens)**2 + (1 - spec)**2)

        results.append({
            "cutoff": cutoff,
            "sensitivity": sens,
            "specificity": spec,
            "distance": distance
        })

    results_df = pd.DataFrame(results)

    # smallest distance = optimal cutoff
    best_row = results_df.loc[results_df["distance"].idxmin()]

    return best_row, results_df

# %%
row_100 = df_with_zcta.iloc[[20100]]

print(row_100)
# Out:
#       first_name    last_name middle_name  county_id county_desc race_code  \
# 20100     ROBERT  MILOSHEVSKY         NaN         28        DARE         W
#
#       ethnic_code  zip_code   zcta  prob_white  prob_black  prob_hisp  \
# 20100          NL     27948  27948         NaN         NaN        NaN
#
#        prob_asian
# 20100         NaN

# %%
import numpy as np
import pandas as pd

# Redefining evaluate_cutoff within this cell to fix the error
def evaluate_cutoff(df, prob_col_name, true_race_code_label, cutoff):
    """
    Compute sensitivity and specificity for a given race and cutoff.

    prob_col_name = column with predicted probability for the race (e.g. "prob_black")
    true_race_code_label = the actual race code label in the 'race_code' column (e.g. "B" for Black)
    cutoff   = threshold to test (0.50 ... 1.00)
    """
    pred_positive = df[prob_col_name] > cutoff

    true_positive = df['race_code'] == true_race_code_label


    total_true_positives = true_positive.sum()
    if total_true_positives == 0:
        sensitivity = np.nan
    else:
        sensitivity = (pred_positive & true_positive).sum() / total_true_positives

    total_true_negatives = (~true_positive).sum()
    if total_true_negatives == 0:
        specificity = np.nan
    else:
        specificity = ((~pred_positive) & (~true_positive)).sum() / total_true_negatives

    return sensitivity, specificity

# Redefining find_optimal_cutoff within this cell to fix the error
def find_optimal_cutoff(df, prob_col_name, true_race_code_label):
    cutoffs = np.arange(0.50, 1.01, 0.01)
    results = []

    for cutoff in cutoffs:
        sens, spec = evaluate_cutoff(df, prob_col_name, true_race_code_label, cutoff)
        if not np.isnan(sens) and not np.isnan(spec):
            distance = np.sqrt((1 - sens)**2 + (1 - spec)**2)
        else:
            distance = np.nan

        results.append({
            "cutoff": cutoff,
            "sensitivity": sens,
            "specificity": spec,
            "distance": distance
        })

    results_df = pd.DataFrame(results)

    if results_df["distance"].isnull().all():
        print(f"Warning: All distances are NaN for {prob_col_name}. Cannot find optimal cutoff.")
        # Return a Series with NaN values for consistency
        return pd.Series({"cutoff": np.nan, "sensitivity": np.nan, "specificity": np.nan, "distance": np.nan}), results_df
    else:
        best_row = results_df.loc[results_df["distance"].idxmin()]
        return best_row, results_df


# Mapping for probability columns to actual race codes in df_with_zcta['race_code']
race_prob_cols_mapping = {
    "prob_white": "W",
    "prob_black": "B",
    "prob_hisp": "HL", # Assuming 'HL' for Hispanic based on previous cells
    "prob_asian": "A"  # Assuming 'A' for Asian based on typical race codes
}

optimal_cutoffs = {}
print("size:" + str(df_with_zcta.size))

for prob_col_name, true_race_code_label in race_prob_cols_mapping.items():
    print(f"\nEvaluating {prob_col_name} against actual race code '{true_race_code_label}'...")
    best, roc_table = find_optimal_cutoff(df_with_zcta, prob_col_name, true_race_code_label)
    optimal_cutoffs[prob_col_name] = best["cutoff"]
    print(best)
# Out:
# size:1300013
#
# Evaluating prob_white against actual race code 'W'...
# cutoff         0.650000
# sensitivity    0.784479
# specificity    0.759383
# distance       0.323026
# Name: 15, dtype: float64
#
# Evaluating prob_black against actual race code 'B'...
# cutoff         0.500000
# sensitivity    0.573564
# specificity    0.915288
# distance       0.434769
# Name: 0, dtype: float64
#
# Evaluating prob_hisp against actual race code 'HL'...
# cutoff         0.500000
# sensitivity    0.669182
# specificity    0.962674
# distance       0.332917
# Name: 0, dtype: float64
#
# Evaluating prob_asian against actual race code 'A'...
# cutoff         0.510000
# sensitivity    0.522192
# specificity    0.992371
# distance       0.477869
# Name: 1, dtype: float64

# %%
# # Redefining evaluate_cutoff within this cell to fix the error
# def evaluate_cutoff(df, prob_col_name, true_race_code_label, cutoff):
#   # print(f"{df.head()}\nProb Column: {prob_col_name}, True Race: {true_race_code_label}, Cutoff: {cutoff}")
#   pred_positive = df[prob_col_name] > cutoff

#   true_positive = df['race_code'] == true_race_code_label


#   total_true_positives = true_positive.sum()
#   # print("total true positives: " + str(total_true_positives))
#   if total_true_positives == 0:
#       sensitivity = 0
#   else:
#       sensitivity = (pred_positive & true_positive).sum() / total_true_positives

#   total_true_negatives = (~true_positive).sum()
#   # print("total true negatives: " + str(total_true_negatives))

#   if total_true_negatives == 0:
#       specificity = 0
#   else:
#       specificity = ((~pred_positive) & (~true_positive)).sum() / total_true_negatives

#   # print("sensitivity: " + str(sensitivity) + " specificity: " + str(specificity))
#   return sensitivity, specificity

# # Redefining find_optimal_cutoff within this cell to fix the error
# def find_optimal_cutoff(df, prob_col_name, true_race_code_label):

#     cutoffs = np.arange(0.50, 1.01, 0.01)
#     results = []

#     for cutoff in cutoffs:
#         sens, spec = evaluate_cutoff(df, prob_col_name, true_race_code_label, cutoff)
#         if not np.isnan(sens) and not np.isnan(spec):
#             distance = np.sqrt((1 - sens)**2 + (1 - spec)**2)
#         else:
#             distance = np.nan

#         results.append({
#             "cutoff": cutoff,
#             "sensitivity": sens,
#             "specificity": spec,
#             "distance": distance
#         })

#     results_df = pd.DataFrame(results)

#     if results_df["distance"].isnull().all():
#         print(f"Warning: All distances are NaN for {prob_col_name}. Cannot find optimal cutoff.")
#         # Return a Series with NaN values for consistency
#         return pd.Series({"cutoff": np.nan, "sensitivity": np.nan, "specificity": np.nan, "distance": np.nan}), results_df
#     else:
#         best_row = results_df.loc[results_df["distance"].idxmin()]
#         return best_row, results_df


# # Mapping for probability columns to actual race codes in df_with_zcta['race_code']
# race_prob_cols_mapping = {
#     "prob_white": "W",
#     "prob_black": "B",
#     "prob_hisp": "HL", # Assuming 'HL' for Hispanic based on previous cells
#     "prob_asian": "A"  # Assuming 'A' for Asian based on typical race codes
# }

# optimal_cutoffs = {}
# print("size:" + str(df_with_zcta.size))

# for prob_col_name, true_race_code_label in race_prob_cols_mapping.items():
#     print(f"\nEvaluating {prob_col_name} against actual race code '{true_race_code_label}'...")
#     best, roc_table = find_optimal_cutoff(df_with_zcta.head(20), prob_col_name, true_race_code_label)
#     optimal_cutoffs[prob_col_name] = best["cutoff"]
#     print(best)
